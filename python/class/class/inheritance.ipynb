# %%
class car:
    def setenginemodel(self,engine):
        self.engine=engine
    def getenginemodel(self):
        print(self.engine)
class tyre:
    def settyrenumber(self,num):
        self.num=num
    def gettyrenumber(self):
        print(self.num)
        
class Honda(car,tyre):
    def setcarmodel(self,model):
        self.model=model
    def getcarmodel(self):
        print(self.model)
accord=Honda()
accord.setenginemodel('Ak-1')
accord.setcarmodel('v10')
accord.settyrenumber(236)
print('car details:')
accord.getenginemodel()
accord.getcarmodel()
accord.gettyrenumber()
# Out:
# car details:
# Ak-1
# v10
# 236
