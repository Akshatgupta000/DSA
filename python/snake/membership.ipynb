# %%
a="good morning"
print("a" not in a)
print("m" not in a)
# Out:
# True
# False

# %%
a=input()
print(3*a[::-1])
# Out:
# olleholleholleh

# %%
a=input()
print(a[::-1])
# Out:
# olleh

# %%
# write a program to print 3 copies of first three characters of a string if length of string is greater than 3 otherwise print the string.
a=input()
if len(a)>3:
    print((a[0]+a[1]+a[2])*3)
else:
    print(a)
# Out:
# helhelhel

# %%
a=input()
b=int(input())
print(a[:b]*b)
# Out:
# akshakshakshaksh
