# %%
# tuples -> a collection of objects separated by commas

t = (3,5,23,23)

print(t.count(5))
print(t.index(23))
# Out:
# 1
# 2

# %%
# DIFFERENCE B/W LIST AND TUPLES
# tuples ko change nhi kr sakte
