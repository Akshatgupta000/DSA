# %%
def hello():
    print("hello")
    
hello()
sales=6000
profit=2000
ad=1000

sales=6000
profit=2000
ad=1000
# Out:
# hello

# %%
class person:
    name="hello"
    occupation="software engineer"
    networth=100
    def info(self):
        print(f"{self.name} is a {self.occupation}")
a=person()
a.name="hero"
a.occupation="Banker"

print(a.name)
print(a.occupation)
# Out:
# hero
# Banker

# %%
class person:
    name="harry"
    occupation="software engineer"
    def info(self):
        print(f"{self.name} is a {self.occupation}")

a=person()
b=person()
c=person()

a.name="rockstar"
a.occupation="life"

b.name="heer"
b.occupation="peace"

c.name="jordan"
c.occupation="dead"
