# %%
age = int(input("Enter your age: "))

if(age>=18):
    print("Yes you can drive")
elif(age == 1):
    print("You are a kid")
else:
    print("No, you can go home")
    
print("End of program")
# Out:
# No, you can go home
# End of program
