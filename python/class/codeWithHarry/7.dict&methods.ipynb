# %%
dict1 = {}
print(type(dict1))
# Out:
# <class 'dict'>

# %%
dict1 = {"good": "Something pleasant", "fetch": "to bring", "1": "The number 1"}

print(dict1["fetch"])
# Out:
# to bring

# %%
marks = {"harshit": 34, "harry": 99, "shivani": 8, "adarsh": 0}

print(marks["adarsh"])

marks["akshat"] = 100
print(marks)
# Out:
# 0
# {'harshit': 34, 'harry': 99, 'shivani': 8, 'adarsh': 0, 'akshat': 100}
