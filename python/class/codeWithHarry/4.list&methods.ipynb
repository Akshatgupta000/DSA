# %%
l1 = [9,5,234,234,234,"Ak"]

print(type(l1))
print(l1)
# l1.remove("Ak")
# print(l1.count(234))
# l1.pop()    #last element remove.
# l1.append(78)  #insertion of an element.
# l1.clear()  #empty element
# l1.extend([89,73,34,2])

print(l1)
# Out:
# <class 'list'>
# [9, 5, 234, 234, 234, 'Ak']
# [9, 5, 234, 234, 234, 'Ak', 89, 73, 34, 2]
