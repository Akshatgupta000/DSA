# %%
a = int(input("Enter number"))

match a:
    case 1:
        print("Case is 1")
    case 2:
        print("Case is 2")
    case 10:
        print("Case is 10")
    case _:
        print("NO match found")
# Out:
# NO match found
