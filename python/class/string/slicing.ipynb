# %%
a="welcome"
print(a[0:2] + a[-2:])
print(a[1:])
print(a[: :-1])  
print(a[4::-1])
# print(a[ :4])
# print(a[ :7])
# print(a[-2])
print(a[:2] + a[-2:])

# %%
str=input("input: ")
if len(str)>2:
    print("output:",str[:2] + str[-2:])
else:
    print("output:",str)
# Out:
# output: weme

# %%
a=input("input:" )
print(a[-1] + a[1:-1] + a[0])
# Out:
# ectivA

# %%
str1="Code"
str2="Tantra"
print(str1+str2+str2+str1)
# Out:
# CodeTantraTantraCode

# %%
a="himynameis"
a.split(",")
# Out:
# ['himynameis']

# %%
a=input()
print(a[::-1])
# Out:
# olleh
