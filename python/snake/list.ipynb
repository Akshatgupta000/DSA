# %%
a=["hi","hello","namaste"]
print(a)
# Out:
# ['hi', 'hello', 'namaste']

# %%
# list constructor
list=list(("apple","banana","mango"))
print(list)
# Out:
# ['apple', 'banana', 'mango']

# %%
# length of list
a=["apple","mango","banana"]
print(len(a))
# Out:
# 3

# %%
a=["apple","banana","mango"]
print(type(a))
# Out:
# <class 'list'>

# %%
# access items 
a=["apple","banana","mango"]
print(a[2])
# Out:
# mango

# %%
# check if items exist
a=["apple","banana","mango"]
if "apple" in a:
    print("yes")
# Out:
# yes

# %%
# change item value
a=["apple","banana","mango"]
a[2]="blackcurrant"
print(a)
# Out:
# ['apple', 'banana', 'blackcurrant']

# %%
# change a range of items values
a=["apple","banana","mango"]
a[0:2]=["blackcurrant","watermelon"]
print(a)
# Out:
# ['blackcurrant', 'watermelon', 'mango']

# %%
# insert items without replacing at a specified index
a=["apple","banana","mango"]
a.insert(2,"watermelon")
print(a)
# Out:
# ['apple', 'banana', 'watermelon', 'mango']

# %%
# insert items at the end
a=["apple","mango","banana"]
a.append("orange")
print(a)
# Out:
# ['apple', 'mango', 'banana', 'orange']

# %%
# extend list
a=["apple","mango","banana"]
b=["watermelon","guava","grapes"]
a.extend(b)
print(a)
# Out:
# ['apple', 'mango', 'banana', 'watermelon', 'guava', 'grapes']

# %%
# remove specified items
a=["apple","mango","banana"]
a.remove("apple")
print(a)
# Out:
# ['mango', 'banana']

# %%
# remove specified index
a=["apple","mango","banana"]
a.pop(1)
print(a)
# Out:
# ['apple', 'banana']

# %%
# clear list
a=["apple","mango","banana"]
a.clear()
print(a)
# Out:
# []

# %%
# looping through a list

a=["apple","mango","banana"]
for x in a:
    print(x)
# Out:
# apple
# mango
# banana

# %%
# loop through index numbers
a=["apple","mango","banana"]
for i in range(len(a)):
    print(a[i])
# Out:
# apple
# mango
# banana

# %%
# using while loop
a=["apple","mango","banana"]
i=0
while i<len(a):
    print(a[i])
    i=i+1
# Out:
# apple
# mango
# banana

# %%
# looping using list commprehension
a=["apple","mango","banana"]
[print(x) for x in a]
# Out:
# apple
# mango
# banana
# [None, None, None]

# %%
# sort list alphanumerically
a=["apple","mango","banana"]
a.sort()
print(a)
# Out:
# ['apple', 'banana', 'mango']

# %%
# sort decending
a=["apple","mango","banana"]
a.sort(reverse=True)
print(a)
# print(a.sort(a))
# Out:
# ['mango', 'banana', 'apple']

# %%
list1=["hi","hello","lists"]
print(list1[0]+list1[1]+list1[2])
print(list1)
list1.append("Code is Life")
print(list1)
list1.extend([45,67,89])
print(list1)
# Out:
# hihellolists
# ['hi', 'hello', 'lists']
# ['hi', 'hello', 'lists', 'Code is Life']
# ['hi', 'hello', 'lists', 'Code is Life', 45, 67, 89]

# %%
# write a program to find whether a given element in a list is present or not.
data=["python","java","c++"]
element=input()

print(element in data)
# Out:
# False

# %%
# write a program to print the first and last element of a list.
data=["hi","hello","welcome"]
print("first and last:",data[0]+" "+data[-1])
# Out:
# first and last: hi welcome

# %%
a=input()
list=a.split(",")
print(list[len(list)-1])
if(list[0]=='3'):
    print("true")
elif(list[len(list)-1]=='3'):
    print("true")
else:
    print("false")
# Out:
# 7
# false

# %%
# create two list and find whether the list contain same element or not.
a=input()
b=input()
print(a==b)
# Out:
# False

# %%
a=input()
if(a[0]==a[-1]):
    print("EQUAL")
else:
    print("NOT EQUAL")
# Out:
# EQUAL

# %%
a=input("data: ")
list1=a.split(",")
# size=len(list1)
# for i in range(size):
#     list1[i]==int(list1[i])
print(list1)
# Out:
# ['1', '2', '3', '4']
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
list1=input()
list2=input()
for item in list1:
    if item in list1

# %%
a=input("")
b=dict(a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\python\snake\list.ipynb Cell 29 line 2
#       <a href='vscode-notebook-cell:/d%3A/python/snake/list.ipynb#X41sZmlsZQ%3D%3D?line=0'>1</a> a=input("")
# ----> <a href='vscode-notebook-cell:/d%3A/python/snake/list.ipynb#X41sZmlsZQ%3D%3D?line=1'>2</a> b=dict(a)
#
# ValueError: dictionary update sequence element #0 has length 1; 2 is required
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
