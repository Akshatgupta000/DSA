# %%
# set -> collection of well defined elements
# ek element ko ek barr print karega

a1 = {3,5,23,5,5,5}
a2 = {3,5,23,7,8,0}
# print(a1.pop())     #koi random element set me se nikal liya
# a1.add(2)
print(a1.union(a2))
print(a1.intersection(a2))
print(a1)
print(a2)
# Out:
# {0, 3, 5, 7, 8, 23}
# {3, 5, 23}
# {3, 5, 23}
# {0, 3, 23, 5, 7, 8}
