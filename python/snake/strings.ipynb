# %%
a=input()
print(a)
# Out:
# Aks

# %%
# string length
a="hello world"
print(len(a))
# Out:
# 11

# %%
# To check if a certain phrase or character is present in a string,
# we can use the keyword in.

a="hello world"
if "hello" in a:
    print("yes")
# Out:
# yes

# %%
# To check if a certain phrase or character is NOT present in a string,
# we can use the keyword not in.

a="hello world"
if "hi" not in a:
    print("no")
# Out:
# no

# %%
# slicing strings
b="hello world"
print(b[2:7])
print(b[:7]) #slicing from start
print(b[7:]) #slicing to end
# Out:
# llo w
# hello w

# %%
# python modify strings
a=" Hello World "
print(a.upper())
print(a.lower())
print(a.strip()) #remove whitespace
print(a.replace("H" , "J")) #replace string
print(a.split(","))
# Out:
#  HELLO WORLD
#  hello world
# Hello World
#  Jello World
# [' Hello World ']

# %%
# string format
age=20
# Z="my name is jack, I am " + age
# print(Z)
# we cannot combine string with nubers so we use string format
Z="my name is jack, I am {}"
print(Z.format(age))
# Out:
# my name is jack, I am 20

# %%
quantity=4
item=5
price=500
myorder="i want {} pieces of items {} for {} rupees"
print(myorder.format(quantity,item,price))
# Out:
# i want 4 pieces of items 5 for 500 rupees

# %%
# Escape character \"
# To insert characters that are illegal in a string, use an escape character.
a="we are the so called \"Vikings\" from the north"
print(a)
# Out:
# we are the so called "Vikings" from the north
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# program to print first two and last two characters of string if length is>2 .
a=input()
if len(a)>3:
    print(a[:2]+a[-2:])
else:
    print(a)
# Out:
# coba

# %%
# write a program to print a string after removing first and last characters.
a=input()
print(a[1:-1])
# Out:
# ell

# %%
# write a program to print a string after exchanging first and last characters of a string
a=input()
print(a[-1]+a[1:-1]+a[0])
# Out:
# oellh

# %%
# write a program to print two strings like str1str2str2str1 format.
a=input()
b=input()
print(a+b+b+a)
# Out:
# helloakshatakshathello

# %%
# write a program to remove a character from string based on user input value
a=input()
b=int(input())
print(a[:b]+a[b+1:])
# Out:
# hi

# %%
# concatenation
a=input()
b=input()
print(a+" "+b)
# Out:
# 5 4

# %%
# write a program to print concatenation of a string, except first character of a string.
a=input()
b=input()
print(a[1:]+" "+b[1:])
# Out:
# ii ello

# %%
str1=input()
str2=input()
print(str1+" "+str2)
# Out:
# hi hello

# %%
a="Big Data"
b="Python"
print(b+a+b)
# Out:
# PythonBig DataPython

# %%
a=input()
print(a.startswith('H'))
# Out:
# True

# %%
a=input()
if a.startswith('Python'):
    print(a)
else:
    print(a+" "+"Python")
# Out:
# hello Python

# %%
# write a program to take string as input from user and reverse the given string using slicing operator.
a=input()
# b=len(a)
print(a[::-1])
# Out:
# olleh

# %%
# write a program to find the number of times a particular sub string appears in a given string. 
a=input()
b=input()
print(a.count(b))
# Out:
# 2

# %%
a=input()
b=len(a)//2
if(len(a)%2==0):
    print()
# Out:
# 5

# %%
a=input("naam kya hai:")
b=input("us me kaha kaha gaye ho:")
c=input("name bataiye")
if(a=="naam kya hai"):
    print("bhupendra jogi")

if(b=="us me kaha  kaha gaye ho"):
    print("us me bhaut jagah gaya hu")

if(c=="naam bataiye"):
    print("bhupendra jogi")
# Out:
# bhupendra jogi
